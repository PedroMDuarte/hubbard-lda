# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 

import scubic
import lda
    
from colorChooser import rgb_to_hex, cmapCycle


aS      = 290. * ( 12. )  / 11.1 
s       = 7.
g       = 3.666
wIR     = 47.
wGR     = 47./1.175
T       = 0.035
extents = 30.
direc   = '111'
mu0     = 'halfMott'
select = 'nlce'
muPlus = 0.

pot = scubic.sc(allIR=s, allGR=g, allIRw=wIR, allGRw=wGR)

lda0 = lda.lda(potential = pot, Temperature=T, a_s=aS, \
               extents=extents, \
               globalMu=mu0, halfMottPlus=muPlus,\
               verbose=True, \
               select = select,\
               ignoreExtents=False, ignoreSlopeErrors=True, \
               ignoreMuThreshold=True)

fig = lda.CheckInhomogTrap( lda0 )
# Out:
# OK: Bottom of the band has positive slope up to r111 = 10 um
# OK: Chemical potential is below evaporation threshold.
# OK: Chemical potential is below the bottom of the band along 100
# ERROR: Radial density profile along 111 has a positive slope
# radius check start =  0.001
# [  9.98904740e-01   9.99125824e-01   9.99420731e-01   9.99109973e-01
#    9.97750673e-01   9.95371322e-01   9.91123362e-01   9.85866217e-01
#    9.79109871e-01   9.68828979e-01   9.55018953e-01   9.37878667e-01
#    9.16081828e-01   8.88865552e-01   8.54161176e-01   8.12422953e-01
#    7.62171737e-01   7.05533625e-01   6.41256859e-01   5.70531678e-01
#    4.95288482e-01   4.21403012e-01   3.50348081e-01   2.81707103e-01
#    2.18263884e-01   1.60967051e-01   1.12997223e-01   7.47695288e-02
#    4.41335507e-02   2.38447159e-02   1.22021685e-02   4.52276667e-03
#    1.40255621e-03   8.50948108e-04   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00]
# [ True  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False]
